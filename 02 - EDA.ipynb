# %%
import pandas as pd

# %%
df =pd.read_csv("Premier_League_Season.csv")

# %%
# Goal Difference: Create new features for goal difference, both at half-time and full-time:
df['GoalDiff_HT'] = df['HTHG'] - df['HTAG']
df['GoalDiff_FT'] = df['FTHG'] - df['FTAG']

# Total Shots: Combine shots and shots on target for both teams:
df['TotalHomeShots'] = df['HS'] + df['HST']
df['TotalAwayShots'] = df['AS'] + df['AST']

# %%
df.head()
# Out:
#       HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR        Referee  \
# 0  Bournemouth  Aston Villa     0     1   A     0     0   D  M Clattenburg
# 1      Chelsea      Swansea     2     2   D     2     1   H       M Oliver
# 2      Everton      Watford     2     2   D     0     1   A        M Jones
# 3    Leicester   Sunderland     4     2   H     3     0   H        L Mason
# 4   Man United    Tottenham     1     0   H     1     0   H         J Moss
#
#    HS  ...  WHD   WHA  PSCH  PSCD   PSCA  Season  GoalDiff_HT  GoalDiff_FT  \
# 0  11  ...  3.5   4.0  1.82  3.88   4.70    2015            0           -1
# 1  11  ...  4.0  10.0  1.37  5.04  10.88    2015            1            0
# 2  10  ...  3.5   5.0  1.75  3.76   5.44    2015           -1            0
# 3  19  ...  3.1   2.7  1.79  3.74   5.10    2015            3            2
# 4   9  ...  3.6   6.0  1.64  4.07   6.04    2015            1            1
#
#    TotalHomeShots  TotalAwayShots
# ...

# %%
print(df.isna())
# Out:
#       HomeTeam  AwayTeam   FTHG   FTAG    FTR   HTHG   HTAG    HTR  Referee  \
# 0        False     False  False  False  False  False  False  False    False
# 1        False     False  False  False  False  False  False  False    False
# 2        False     False  False  False  False  False  False  False    False
# 3        False     False  False  False  False  False  False  False    False
# 4        False     False  False  False  False  False  False  False    False
# ...        ...       ...    ...    ...    ...    ...    ...    ...      ...
# 3425     False     False  False  False  False  False  False  False    False
# 3426     False     False  False  False  False  False  False  False    False
# 3427     False     False  False  False  False  False  False  False    False
# 3428     False     False  False  False  False  False  False  False    False
# 3429     False     False  False  False  False  False  False  False    False
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3430 entries, 0 to 3429
# Data columns (total 38 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   HomeTeam        3430 non-null   object
#  1   AwayTeam        3430 non-null   object
#  2   FTHG            3430 non-null   int64
#  3   FTAG            3430 non-null   int64
#  4   FTR             3430 non-null   object
#  5   HTHG            3430 non-null   int64
#  6   HTAG            3430 non-null   int64
#  7   HTR             3430 non-null   object
#  8   Referee         3430 non-null   object
#  9   HS              3430 non-null   int64
#  10  AS              3430 non-null   int64
#  11  HST             3430 non-null   int64
#  12  AST             3430 non-null   int64
#  13  HF              3430 non-null   int64
#  14  AF              3430 non-null   int64
#  15  HC              3430 non-null   int64
#  16  AC              3430 non-null   int64
# ...

# %%
df.describe()
# Out:
#               FTHG         FTAG         HTHG         HTAG           HS  \
# count  3430.000000  3430.000000  3430.000000  3430.000000  3430.000000
# mean      1.554227     1.262099     0.688921     0.562099    13.925364
# std       1.325591     1.214688     0.846842     0.771744     5.751663
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     0.000000     0.000000     0.000000    10.000000
# 50%       1.000000     1.000000     0.000000     0.000000    13.000000
# 75%       2.000000     2.000000     1.000000     1.000000    17.000000
# max       9.000000     9.000000     5.000000     5.000000    37.000000
#
#                 AS          HST          AST           HF           AF  ...  \
# count  3430.000000  3430.000000  3430.000000  3430.000000  3430.000000  ...
# mean     11.433236     4.771720     3.998834    10.516618    10.879009  ...
# std       5.002892     2.665587     2.366900     3.433090     3.572716  ...
# ...

# %%
# counting FTR using barplot
import seaborn as sns
import matplotlib.pyplot as plt

# Check if 'FTR' column exists in df
if 'FTR' in df.columns:
    # Create a barplot to count occurrences of FTR (Full-Time Result)
    sns.countplot(x='FTR', data=df)

    # Add labels and title
    plt.title('Count of Full-Time Results (FTR)')
    plt.xlabel('Full-Time Result')
    plt.ylabel('Count')

    # Show the plot
    plt.show()
else:
    print("Column 'FTR' not found in the dataframe")

# %%
# counting FTR using barplot GoalDiff_HT	GoalDiff_FT	TotalHomeShots	TotalAwayShots

# Check if 'FTR' column exists in df
if 'FTR' in df.columns:
    # Create a barplot to count occurrences of FTR (Full-Time Result)
    sns.countplot(x='FTR', data=df)

    # Add labels and title
    plt.title('Count of Full-Time Results (FTR)')
    plt.xlabel('Full-Time Result')
    plt.ylabel('Count')

    # Show the plot
    plt.show()
else:
    print("Column 'FTR' not found in the dataframe")

# %%
# Set up the plot size and style
plt.figure(figsize=(8,6))
sns.set(style="whitegrid")

# Create the bar plot to count occurrences of Full-Time Result (FTR)
sns.countplot(x='FTR', data=df, palette='Set2')

# Add title and labels
plt.title('Count of Full-Time Result (FTR)', fontsize=14)
plt.xlabel('Full-Time Result (FTR)', fontsize=12)
plt.ylabel('Count', fontsize=12)

# Show the plot
plt.show()

# %%
# Import libraries (assuming pandas is already imported)
import pandas as pd

# Get the counts
ftr_counts = df['FTR'].value_counts()

# Print the counts
print(ftr_counts)
# Out:
# FTR
# H    1540
# A    1095
# D     795
# Name: count, dtype: int64

# %%
# Set the figure size
plt.figure(figsize=(10, 6))

# Prepare the data for plotting
df_melted = pd.melt(df, value_vars=['TotalHomeShots', 'TotalAwayShots'],
                    var_name='Metrics', value_name='Values')

# Create the bar plot
sns.barplot(x='Metrics', y='Values', data=df_melted)

# Add a title and labels
plt.title('Total Shots Comparison')
plt.xlabel('Metrics')
plt.ylabel('Values')

# Show the plot
plt.show()

# %%
# Import libraries (assuming pandas is already imported)
import pandas as pd

# Get the counts of total shots comparaison
totalshots_counts1 = df['TotalHomeShots'].sum()
# Get the counts of total shots comparaison
totalshots_counts2 = df['TotalAwayShots'].sum()

# Print the counts
print(totalshots_counts1)
print(totalshots_counts2)
# Out:
# 64131
# 52932

# %%
# print all the columns
# for column in df.columns:
#     print(column)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Define the columns to include in the box plot (excluding FTR and HTR)
columns_to_plot = [
    'FTHG',  # Full Time Home Goals
    'FTAG',  # Full Time Away Goals
    'HTHG',  # Half Time Home Goals
    'HTAG',  # Half Time Away Goals
    'HS',    # Home Shots
    'AS',    # Away Shots
    'HST',   # Home Shots on Target
    'AST',   # Away Shots on Target
    'HF',    # Home Fouls
    'AF',    # Away Fouls
    'HC',    # Home Corners
    'AC',    # Away Corners
    'HY',    # Home Yellow Cards
    'AY',    # Away Yellow Cards
    'HR',    # Home Red Cards
    'AR'     # Away Red Cards
]

# Filter the DataFrame to include only the specified columns
data_to_plot = df[columns_to_plot]

# Create a horizontal box plot
plt.figure(figsize=(8, 6))
sns.boxplot(data=data_to_plot, orient='h')

# Set plot labels and title
plt.yticks(rotation=0)
plt.title('Horizontal Box Plot of Football Match Metrics')
plt.xlabel('Values')
plt.ylabel('Metrics')

# Show plot
plt.tight_layout()
plt.show()

# %%
# Combine HomeTeam and AwayTeam into a single series and get unique team names
unique_teams = pd.concat([df['HomeTeam'], df['AwayTeam']]).unique()

# Create a mapping of team names to unique IDs
team_id_mapping = {team: idx for idx, team in enumerate(unique_teams)}

# Map the team names to IDs in the DataFrame
df['HomeTeam_ID'] = df['HomeTeam'].map(team_id_mapping)
df['AwayTeam_ID'] = df['AwayTeam'].map(team_id_mapping)

# Display the number of unique teams and a sample of the team ID mapping
print(f"Number of unique teams: {len(unique_teams)}")
print("Sample team ID mapping:", list(team_id_mapping.items())[:10])
# Out:
# Number of unique teams: 34
# Sample team ID mapping: [('Bournemouth', 0), ('Chelsea', 1), ('Everton', 2), ('Leicester', 3), ('Man United', 4), ('Norwich', 5), ('Arsenal', 6), ('Newcastle', 7), ('Stoke', 8), ('West Brom', 9)]

# %%
# Set the 'Season' column as the index to use tha column later on for splitting our dataset
df.set_index('Season', inplace=True)

# Save the DataFrame to a CSV file with the new index
df.to_csv('Premier_League_Season_With_Team_IDs.csv')

# Optional: Check if everything worked correctly by displaying the first few rows
print(df.head())
# Out:
#            HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# Season
# 2015    Bournemouth  Aston Villa     0     1   A     0     0   D
# 2015        Chelsea      Swansea     2     2   D     2     1   H
# 2015        Everton      Watford     2     2   D     0     1   A
# 2015      Leicester   Sunderland     4     2   H     3     0   H
# 2015     Man United    Tottenham     1     0   H     1     0   H
#
#               Referee  HS  ...   WHA  PSCH  PSCD   PSCA  GoalDiff_HT  \
# Season                     ...
# 2015    M Clattenburg  11  ...   4.0  1.82  3.88   4.70            0
# 2015         M Oliver  11  ...  10.0  1.37  5.04  10.88            1
# 2015          M Jones  10  ...   5.0  1.75  3.76   5.44           -1
# 2015          L Mason  19  ...   2.7  1.79  3.74   5.10            3
# 2015           J Moss   9  ...   6.0  1.64  4.07   6.04            1
#
#         GoalDiff_FT  TotalHomeShots  TotalAwayShots  HomeTeam_ID  AwayTeam_ID
# Season
# ...

# %%
# Filter the DataFrame to include only the specified columns
df_filtered = df[columns_to_plot]

# Compute the correlation matrix
corr_matrix = df_filtered.corr()

# Plotting the heatmap
plt.figure(figsize=(8, 6))
heatmap = sns.heatmap(
    corr_matrix,
    annot=True,          # Add values in each square
    cmap='coolwarm',     # Color map
    fmt='.2f',           # Format for the values
    linewidths=0.5,      # Line width between squares
    vmin=-1, vmax=1      # Color scale limits
)

# Improve the visual aesthetics
plt.title('Correlation Heatmap of Football Metrics', fontsize=16)
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()

plt.show()

# %%
# Compute the correlation matrix
corr_matrix = df_filtered.corr()

# Print the correlation matrix
print("Correlation Matrix:")
print(corr_matrix)

# The correlation matrix of various football metrics reveals several noteworthy patterns in the relationships between match statistics. Full Time Home Goals (FTHG) and Full Time Away Goals (FTAG) exhibit a negative correlation of -0.14, indicating that while there is a slight tendency for more goals scored by one team, it does not strongly influence the other team’s performance. Half Time Home Goals (HTHG) and Full Time Home Goals (FTHG) show a strong positive correlation (0.70), suggesting that teams which perform well in the first half are likely to continue this performance through the match. Conversely, Half Time Away Goals (HTAG) is moderately correlated with Full Time Away Goals (FTAG) (0.70), indicating a consistent performance trend for away teams as well.

# The number of Home Shots (HS) and Home Shots on Target (HST) are highly correlated (0.69), reflecting that teams with more shots generally have more on-target attempts. Away Shots (AS) and Away Shots on Target (AST) also show a strong correlation (0.69), similar to home metrics, suggesting that away teams follow a similar pattern of shot accuracy.

# Interestingly, the metrics related to fouls, such as Home Fouls (HF) and Away Fouls (AF), exhibit weak correlations with other variables, indicating that fouls have less impact on the outcome compared to other factors. Similarly, Home Corners (HC) and Away Corners (AC) are moderately correlated with goals scored, indicating a possible link between corner opportunities and scoring potential.

# The correlation between Home Yellow Cards (HY) and Away Yellow Cards (AY) is relatively low (0.08), highlighting that disciplinary actions are more team-specific rather than universally affecting match outcomes. The Home Red Cards (HR) and Away Red Cards (AR), on the other hand, show a minimal negative correlation (-0.005), suggesting that the presence of red cards in a game is not strongly related between home and away teams.

# Overall, the correlation analysis underscores the significant impact of shots and goals on match outcomes, while other factors like fouls and disciplinary actions have a more nuanced or weaker effect.
# Out:
# Correlation Matrix:
#           FTHG      FTAG      HTHG      HTAG        HS        AS       HST  \
# FTHG  1.000000 -0.137694  0.697367 -0.089098  0.330474 -0.191051  0.603564
# FTAG -0.137694  1.000000 -0.085432  0.704531 -0.164209  0.355484 -0.164356
# HTHG  0.697367 -0.085432  1.000000 -0.078643  0.144377 -0.061451  0.395384
# HTAG -0.089098  0.704531 -0.078643  1.000000 -0.071488  0.209055 -0.105880
# HS    0.330474 -0.164209  0.144377 -0.071488  1.000000 -0.432010  0.689942
# AS   -0.191051  0.355484 -0.061451  0.209055 -0.432010  1.000000 -0.302152
# HST   0.603564 -0.164356  0.395384 -0.105880  0.689942 -0.302152  1.000000
# AST  -0.159201  0.604761 -0.080495  0.430147 -0.286397  0.686650 -0.222283
# HF   -0.060115 -0.008493 -0.040602  0.000106 -0.087208  0.034355 -0.038257
# AF   -0.011515 -0.028575  0.007413 -0.010019 -0.012701 -0.053161 -0.014293
# HC    0.055301 -0.099180 -0.030238 -0.032962  0.553939 -0.346060  0.326844
# ...

# %% [markdown]
# # End
